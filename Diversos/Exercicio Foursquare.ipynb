# %% [markdown]
# Teste foursquare

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 

# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

import json

import os
import branca
import io
#import plotly.graph_objs as go 
#from plotly.offline import plot

print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %%
#CLIENT_ID = 'T1F14ZSMPK4DKKGTZASK3MLJU0RMKYNKQXTIYYW3SSTJHY4W' # your Foursquare ID
#CLIENT_SECRET = 'ATJZAHQ1BW4ODDIPDNVPTR1D3ZTLPVNQAGBTJX1JMUIMKQLE' # your Foursquare Secret
VERSION = '20180604'

#print('Your credentails:')
#print('CLIENT_ID: ' + CLIENT_ID)
#print('CLIENT_SECRET:' + CLIENT_SECRET)

# %%
url ='https://api.foursquare.com/v2/venues/search?client_id=T1F14ZSMPK4DKKGTZASK3MLJU0RMKYNKQXTIYYW3SSTJHY4W&client_secret=ATJZAHQ1BW4ODDIPDNVPTR1D3ZTLPVNQAGBTJX1JMUIMKQLE&ll=-8.0615379,-34.895044&&v=20180604&categoryId=4bf58dd8d48988d104941735'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f08c256c5cc8e0e203eed4b'},
#  'response': {'venues': [{'id': '4d3791c0803ba35ddf1394fc',
#     'name': 'Hospital Unimed Recife I',
#     'location': {'address': 'Av. Lins Petit, 140',
#      'lat': -8.060745673136815,
#      'lng': -34.8948792156905,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.060745673136815,
#        'lng': -34.8948792156905}],
#      'distance': 90,
#      'postalCode': '50070-230',
#      'cc': 'BR',
#      'city': 'Recife',
#      'state': 'PE',
#      'country': 'Brasil',
#      'formattedAddress': ['Av. Lins Petit, 140',
#       'Recife, PE',
#       '50070-230',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '4bdc97582a3a0f47718cb3b6',
#     'name': 'IMIP - Instituto de Medicina Integral Professor Fernando Figueira',
#     'location': {'address': 'R. dos Coelhos, 300',
#      'lat': -8.066677143803023,
#      'lng': -34.89097026672641,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.066677143803023,
#        'lng': -34.89097026672641}],
#      'distance': 727,
#      'postalCode': '50070-550',
#      'cc': 'BR',
#      'city': 'Recife',
#      'state': 'PE',
#      'country': 'Brasil',
#      'formattedAddress': ['R. dos Coelhos, 300',
#       'Recife, PE',
#       '50070-550',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '54d0ca5d498e1de1dc2e3fd2',
#     'name': 'Clínica ORTHO',
#     'location': {'address': 'Estrada Do Encanamento 459',
#      'lat': -8.031917125509992,
#      'lng': -34.91459831376302,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.031917125509992,
#        'lng': -34.91459831376302}],
#      'distance': 3939,
#      'postalCode': '52060-210',
#      'cc': 'BR',
#      'city': 'Recife',
#      'state': 'PE',
#      'country': 'Brasil',
#      'formattedAddress': ['Estrada Do Encanamento 459',
#       'Recife, PE',
#       '52060-210',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '4c7423a3604a37045c287f49',
#     'name': 'Hospital de Olhos Santa Luzia',
#     'location': {'address': 'Estr. do Encanamento, 909',
#      'crossStreet': 'Casa Forte',
#      'lat': -8.030806306423989,
#      'lng': -34.91824619792266,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.030806306423989,
#        'lng': -34.91824619792266}],
#      'distance': 4271,
#      'postalCode': '52070-000',
#      'cc': 'BR',
#      'city': 'Recife',
#      'state': 'PE',
#      'country': 'Brasil',
#      'formattedAddress': ['Estr. do Encanamento, 909 (Casa Forte)',
#       'Recife, PE',
#       '52070-000',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '5eecf0d14595790008e31dab',
#     'name': 'Hospital Veterinário Harmonia',
#     'location': {'address': 'Av. Domingos Ferreira, 3628, Boa viagem',
#      'lat': -8.120095,
#      'lng': -34.898285,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.120095,
#        'lng': -34.898285}],
#      'distance': 6528,
#      'postalCode': '51020-290',
#      'cc': 'BR',
#      'neighborhood': 'Boa viagem',
#      'city': 'Recife',
#      'state': 'PE',
#      'country': 'Brasil',
#      'formattedAddress': ['Av. Domingos Ferreira, 3628, Boa viagem',
#       'Recife, PE',
#       '51020-290',
#       'Brasil']},
#     'categories': [{'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'shortName': 'Veterinarians',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '54ff80e6498efaf6353456f8',
#     'name': 'UTI João de Deus',
#     'location': {'lat': -8.064878320877478,
#      'lng': -34.898905078016725,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.064878320877478,
#        'lng': -34.898905078016725}],
#      'distance': 565,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '5b3fe7483ba767002cd2d5bb',
#     'name': 'Urct Adulto - Rhp',
#     'location': {'address': 'Av. Gov. Agamenon Magalhães, 4760',
#      'lat': -8.064112,
#      'lng': -34.897926,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.064112,
#        'lng': -34.897926}],
#      'distance': 427,
#      'postalCode': '50030-230',
#      'cc': 'BR',
#      'city': 'Recife',
#      'state': 'PE',
#      'country': 'Brasil',
#      'formattedAddress': ['Av. Gov. Agamenon Magalhães, 4760',
#       'Recife, PE',
#       '50030-230',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '4bfa9f66508c0f4783404031',
#     'name': 'Real Hospital Português',
#     'location': {'address': 'Av. Gov. Agamenon Magalhães, 4760',
#      'lat': -8.064146667815368,
#      'lng': -34.89822097885892,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.064146667815368,
#        'lng': -34.89822097885892}],
#      'distance': 454,
#      'postalCode': '52010-902',
#      'cc': 'BR',
#      'city': 'Recife',
#      'state': 'PE',
#      'country': 'Brasil',
#      'formattedAddress': ['Av. Gov. Agamenon Magalhães, 4760',
#       'Recife, PE',
#       '52010-902',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '57bdae68498edfdbaf5536bc',
#     'name': 'Cure Clínica',
#     'location': {'address': 'Avenida 1 Número 60',
#      'crossStreet': 'Curado IV',
#      'lat': -8.067394,
#      'lng': -34.996402,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.067394,
#        'lng': -34.996402}],
#      'distance': 11190,
#      'postalCode': '54270-090',
#      'cc': 'BR',
#      'city': 'Jaboatão dos Guararapes',
#      'state': 'PE',
#      'country': 'Brasil',
#      'formattedAddress': ['Avenida 1 Número 60 (Curado IV)',
#       'Jaboatão dos Guararapes, PE',
#       '54270-090',
#       'Brasil']},
#     'categories': [{'id': '4f4531b14b9074f6e4fb0103',
#       'name': 'Medical Lab',
#       'pluralName': 'Medical Labs',
#       'shortName': 'Medical Lab',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lab_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '4f7c5701e4b032112a686c7a',
#     'name': 'Hapclínica Boa Viagem',
#     'location': {'lat': -8.12005781822426,
#      'lng': -34.89799399973311,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.12005781822426,
#        'lng': -34.89799399973311}],
#      'distance': 6522,
#      'cc': 'BR',
#      'city': 'Recife',
#      'state': 'PE',
#      'country': 'Brasil',
#      'formattedAddress': ['Recife, PE', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '513735c9e4b08e9b2ab66f5f',
#     'name': 'Hapclínica Barão de Itamaracá',
#     'location': {'address': 'Rua Barão de Itamaracá, 142, Espinheiro',
#      'lat': -8.043626080161125,
#      'lng': -34.89377983185323,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.043626080161125,
#        'lng': -34.89377983185323}],
#      'distance': 1998,
#      'cc': 'BR',
#      'city': 'Recife',
#      'state': 'PE',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua Barão de Itamaracá, 142, Espinheiro',
#       'Recife, PE',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '4d84fc71e83fa1433f3970a1',
#     'name': 'Policlínica e Maternidade Prof. Arnaldo Marques',
#     'location': {'address': 'Av. Dois Rios, s/n',
#      'lat': -8.118559747798724,
#      'lng': -34.94427493777605,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.118559747798724,
#        'lng': -34.94427493777605}],
#      'distance': 8350,
#      'postalCode': '51230-000',
#      'cc': 'BR',
#      'city': 'Recife',
#      'state': 'PE',
#      'country': 'Brasil',
#      'formattedAddress': ['Av. Dois Rios, s/n',
#       'Recife, PE',
#       '51230-000',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '4d99fed5af3d236a079f5fc7',
#     'name': 'Hospital Santa Teresinha',
#     'location': {'lat': -8.037739441040353,
#      'lng': -34.94416418715023,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.037739441040353,
#        'lng': -34.94416418715023}],
#      'distance': 6027,
#      'postalCode': '50800-000',
#      'cc': 'BR',
#      'city': 'Recife',
#      'state': 'PE',
#      'country': 'Brasil',
#      'formattedAddress': ['Recife, PE', '50800-000', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '4c6883826b25e21e56fe192f',
#     'name': 'Real Hospital Português',
#     'location': {'address': 'Av. Conselheiro Aguiar, 2502 - Boa Viagem',
#      'lat': -8.111577227144908,
#      'lng': -34.89188228699823,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.111577227144908,
#        'lng': -34.89188228699823}],
#      'distance': 5581,
#      'postalCode': '51020-020',
#      'cc': 'BR',
#      'city': 'Recife',
#      'state': 'PE',
#      'country': 'Brasil',
#      'formattedAddress': ['Av. Conselheiro Aguiar, 2502 - Boa Viagem',
#       'Recife, PE',
#       '51020-020',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d194941735',
#       'name': 'Emergency Room',
#       'pluralName': 'Emergency Rooms',
#       'shortName': 'Emergency Room',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_ems_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '4cbf3fce9ca85481387ab516',
#     'name': 'Hospital Metropolitano Sul Dom Helder Câmara (HDH)',
#     'location': {'address': 'Rod. BR-101 Sul, Km 28',
#      'lat': -8.250473891375407,
#      'lng': -35.009304693209764,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.250473891375407,
#        'lng': -35.009304693209764}],
#      'distance': 24512,
#      'postalCode': '50751-530',
#      'cc': 'BR',
#      'city': 'Cabo de Santo Agostinho',
#      'state': 'PE',
#      'country': 'Brasil',
#      'formattedAddress': ['Rod. BR-101 Sul, Km 28',
#       'Cabo de Santo Agostinho, PE',
#       '50751-530',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '4d08eb63611ff04d2a861dfb',
#     'name': 'Hospital do Câncer de Pernambuco',
#     'location': {'address': 'Av. Cruz Cabugá, 1597',
#      'lat': -8.041619433879056,
#      'lng': -34.872869502840906,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.041619433879056,
#        'lng': -34.872869502840906}],
#      'distance': 3300,
#      'cc': 'BR',
#      'city': 'Recife',
#      'state': 'PE',
#      'country': 'Brasil',
#      'formattedAddress': ['Av. Cruz Cabugá, 1597', 'Recife, PE', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '4c463f843f0276b097c452e7',
#     'name': 'HBL - Hospital Barão de Lucena',
#     'location': {'address': 'Av. Caxangá, 3860',
#      'crossStreet': 'R. do Palanque',
#      'lat': -8.03824756548555,
#      'lng': -34.939120620992966,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.03824756548555,
#        'lng': -34.939120620992966}],
#      'distance': 5506,
#      'cc': 'BR',
#      'city': 'Recife',
#      'state': 'PE',
#      'country': 'Brasil',
#      'formattedAddress': ['Av. Caxangá, 3860 (R. do Palanque)',
#       'Recife, PE',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '4d68fd774c4637041bbe9bb3',
#     'name': 'Laboratório Marcelo Magalhães',
#     'location': {'address': 'R. Raul Azedo,252',
#      'crossStreet': 'Boa Viagem',
#      'lat': -8.101747019813569,
#      'lng': -34.88695910525088,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.101747019813569,
#        'lng': -34.88695910525088}],
#      'distance': 4563,
#      'postalCode': '51011-051',
#      'cc': 'BR',
#      'city': 'Recife',
#      'state': 'PE',
#      'country': 'Brasil',
#      'formattedAddress': ['R. Raul Azedo,252 (Boa Viagem)',
#       'Recife, PE',
#       '51011-051',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '4dff478552b1d747f679127b',
#     'name': 'Hospital Correia Picanço - HCP',
#     'location': {'lat': -8.03415804358344,
#      'lng': -34.90463621210976,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.03415804358344,
#        'lng': -34.90463621210976}],
#      'distance': 3226,
#      'cc': 'BR',
#      'city': 'Recife',
#      'state': 'PE',
#      'country': 'Brasil',
#      'formattedAddress': ['Recife, PE', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '4d9baa7dc18aa35d4e0f73ff',
#     'name': 'Hospital Getúlio Vargas',
#     'location': {'address': 'Av. Gal. San Martin, 200',
#      'crossStreet': 'Av. Caxangá',
#      'lat': -8.051765463332268,
#      'lng': -34.92203192900747,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.051765463332268,
#        'lng': -34.92203192900747}],
#      'distance': 3167,
#      'postalCode': '50630-060',
#      'cc': 'BR',
#      'city': 'Recife',
#      'state': 'PE',
#      'country': 'Brasil',
#      'formattedAddress': ['Av. Gal. San Martin, 200 (Av. Caxangá)',
#       'Recife, PE',
#       '50630-060',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '52e7aa23498e4057e2a9402d',
#     'name': 'Hospital da Mulher do Recife',
#     'location': {'address': 'BR101',
#      'lat': -8.071000797189791,
#      'lng': -34.94011861471061,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.071000797189791,
#        'lng': -34.94011861471061}],
#      'distance': 5078,
#      'cc': 'BR',
#      'city': 'Recife',
#      'state': 'PE',
#      'country': 'Brasil',
#      'formattedAddress': ['BR101', 'Recife, PE', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '4ee77bea490141636ca4dbf5',
#     'name': 'Dento Clínica',
#     'location': {'lat': -8.099284613599364,
#      'lng': -34.934438773534374,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.099284613599364,
#        'lng': -34.934438773534374}],
#      'distance': 6042,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '4d8e24a8fa94370457e7fac5',
#     'name': 'UPA Curado',
#     'location': {'address': 'Av. Leonardo da Vinci',
#      'crossStreet': 'rua lobão botelho',
#      'lat': -8.080684856649567,
#      'lng': -34.99659283294801,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.080684856649567,
#        'lng': -34.99659283294801}],
#      'distance': 11393,
#      'cc': 'BR',
#      'city': 'Jaboatão dos Guararapes',
#      'state': 'PE',
#      'country': 'Brasil',
#      'formattedAddress': ['Av. Leonardo da Vinci (rua lobão botelho)',
#       'Jaboatão dos Guararapes, PE',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '4c476cc4417b20a19b90dda9',
#     'name': 'Hospital Esperança',
#     'location': {'address': 'R. Francisco Alves 887',
#      'lat': -8.067090477968684,
#      'lng': -34.895474910736084,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.067090477968684,
#        'lng': -34.895474910736084}],
#      'distance': 619,
#      'postalCode': '50070-490',
#      'cc': 'BR',
#      'city': 'Recife',
#      'state': 'PE',
#      'country': 'Brasil',
#      'formattedAddress': ['R. Francisco Alves 887',
#       'Recife, PE',
#       '50070-490',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '4bcdb288fb84c9b67b60223e',
#     'name': 'Hospital da Restauração',
#     'location': {'address': 'Av. Gov. Agamenon Magalhães, s/n',
#      'lat': -8.05436168228491,
#      'lng': -34.89752610084915,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.05436168228491,
#        'lng': -34.89752610084915}],
#      'distance': 844,
#      'postalCode': '52010-903',
#      'cc': 'BR',
#      'city': 'Recife',
#      'state': 'PE',
#      'country': 'Brasil',
#      'formattedAddress': ['Av. Gov. Agamenon Magalhães, s/n',
#       'Recife, PE',
#       '52010-903',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '4e8d99f0722e13d13af16c0a',
#     'name': 'Hospital Unimed Recife III',
#     'location': {'address': 'Rua José de Alencar, 770',
#      'lat': -8.064627371656552,
#      'lng': -34.891748895482934,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.064627371656552,
#        'lng': -34.891748895482934}],
#      'distance': 500,
#      'cc': 'BR',
#      'city': 'Recife',
#      'state': 'PE',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua José de Alencar, 770', 'Recife, PE', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '534be4fe498ecb6c1f9a51d3',
#     'name': 'Alergo Imuno - Alergologia E Imunologia',
#     'location': {'address': 'Rua José De Alencar, 725',
#      'lat': -8.06437056701389,
#      'lng': -34.89115260131625,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.06437056701389,
#        'lng': -34.89115260131625}],
#      'distance': 532,
#      'cc': 'BR',
#      'city': 'Recife',
#      'state': 'PE',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua José De Alencar, 725', 'Recife, PE', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '4d8341635e70224b3b38f308',
#     'name': 'Hospital Pedro II',
#     'location': {'address': 'São José',
#      'lat': -8.066906405349105,
#      'lng': -34.89107800843074,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.066906405349105,
#        'lng': -34.89107800843074}],
#      'distance': 740,
#      'cc': 'BR',
#      'city': 'Recife',
#      'state': 'PE',
#      'country': 'Brasil',
#      'formattedAddress': ['São José', 'Recife, PE', 'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '51ca12ece4b0887919f47f8a',
#     'name': 'Rede Ciclo-Consultórios Médicos',
#     'location': {'address': 'Rua Pacífico Dos Santos,n. 103',
#      'lat': -8.063033105451874,
#      'lng': -34.90002218869974,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.063033105451874,
#        'lng': -34.90002218869974}],
#      'distance': 573,
#      'cc': 'BR',
#      'city': 'Recife',
#      'state': 'PE',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua Pacífico Dos Santos,n. 103',
#       'Recife, PE',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False},
#    {'id': '4ea696af2c5b614a68e0af9d',
#     'name': 'Policlínica Lessa de Andrade',
#     'location': {'address': 'Est. dos Remédios, 2416',
#      'crossStreet': 'Madalena',
#      'lat': -8.058828383169216,
#      'lng': -34.90695737629873,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -8.058828383169216,
#        'lng': -34.90695737629873}],
#      'distance': 1347,
#      'cc': 'BR',
#      'city': 'Recife',
#      'state': 'PE',
#      'country': 'Brasil',
#      'formattedAddress': ['Est. dos Remédios, 2416 (Madalena)',
#       'Recife, PE',
#       'Brasil']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594409546',
#     'hasPerk': False}],
#   'confident': False}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d196941735', 'name': 'H...    False
# 1  [{'id': '4bf58dd8d48988d196941735', 'name': 'H...    False
# 2  [{'id': '4bf58dd8d48988d177941735', 'name': 'D...    False
# 3  [{'id': '4bf58dd8d48988d196941735', 'name': 'H...    False
# 4  [{'id': '4d954af4a243a5684765b473', 'name': 'V...    False
#
#                          id                         location.address  \
# 0  4d3791c0803ba35ddf1394fc                      Av. Lins Petit, 140
# 1  4bdc97582a3a0f47718cb3b6                      R. dos Coelhos, 300
# 2  54d0ca5d498e1de1dc2e3fd2               Estrada Do Encanamento 459
# 3  4c7423a3604a37045c287f49                Estr. do Encanamento, 909
# 4  5eecf0d14595790008e31dab  Av. Domingos Ferreira, 3628, Boa viagem
#
#   location.cc location.city location.country location.crossStreet  \
# 0          BR        Recife           Brasil                  NaN
# 1          BR        Recife           Brasil                  NaN
# 2          BR        Recife           Brasil                  NaN
# 3          BR        Recife           Brasil           Casa Forte
# 4          BR        Recife           Brasil                  NaN
#
#    location.distance                          location.formattedAddress  \
# 0                 90  [Av. Lins Petit, 140, Recife, PE, 50070-230, B...
# 1                727  [R. dos Coelhos, 300, Recife, PE, 50070-550, B...
# 2               3939  [Estrada Do Encanamento 459, Recife, PE, 52060...
# 3               4271  [Estr. do Encanamento, 909 (Casa Forte), Recif...
# 4               6528  [Av. Domingos Ferreira, 3628, Boa viagem, Reci...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': -8.06074567313681...     -8.060746
# 1  [{'label': 'display', 'lat': -8.06667714380302...     -8.066677
# 2  [{'label': 'display', 'lat': -8.03191712550999...     -8.031917
# 3  [{'label': 'display', 'lat': -8.03080630642398...     -8.030806
# 4  [{'label': 'display', 'lat': -8.120095, 'lng':...     -8.120095
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -34.894879                   NaN           50070-230             PE
# 1    -34.890970                   NaN           50070-550             PE
# 2    -34.914598                   NaN           52060-210             PE
# 3    -34.918246                   NaN           52070-000             PE
# 4    -34.898285            Boa viagem           51020-290             PE
#
#                                                 name    referralId
# 0                           Hospital Unimed Recife I  v-1594409546
# 1  IMIP - Instituto de Medicina Integral Professo...  v-1594409546
# 2                                      Clínica ORTHO  v-1594409546
# 3                      Hospital de Olhos Santa Luzia  v-1594409546
# 4                      Hospital Veterinário Harmonia  v-1594409546

# %%
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d196941735', 'name': 'H...    False
# 1  [{'id': '4bf58dd8d48988d196941735', 'name': 'H...    False
# 2  [{'id': '4bf58dd8d48988d177941735', 'name': 'D...    False
# 3  [{'id': '4bf58dd8d48988d196941735', 'name': 'H...    False
# 4  [{'id': '4d954af4a243a5684765b473', 'name': 'V...    False
#
#                          id                         location.address  \
# 0  4d3791c0803ba35ddf1394fc                      Av. Lins Petit, 140
# 1  4bdc97582a3a0f47718cb3b6                      R. dos Coelhos, 300
# 2  54d0ca5d498e1de1dc2e3fd2               Estrada Do Encanamento 459
# 3  4c7423a3604a37045c287f49                Estr. do Encanamento, 909
# 4  5eecf0d14595790008e31dab  Av. Domingos Ferreira, 3628, Boa viagem
#
#   location.cc location.city location.country location.crossStreet  \
# 0          BR        Recife           Brasil                  NaN
# 1          BR        Recife           Brasil                  NaN
# 2          BR        Recife           Brasil                  NaN
# 3          BR        Recife           Brasil           Casa Forte
# 4          BR        Recife           Brasil                  NaN
#
#    location.distance                          location.formattedAddress  \
# 0                 90  [Av. Lins Petit, 140, Recife, PE, 50070-230, B...
# 1                727  [R. dos Coelhos, 300, Recife, PE, 50070-550, B...
# 2               3939  [Estrada Do Encanamento 459, Recife, PE, 52060...
# 3               4271  [Estr. do Encanamento, 909 (Casa Forte), Recif...
# 4               6528  [Av. Domingos Ferreira, 3628, Boa viagem, Reci...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': -8.06074567313681...     -8.060746
# 1  [{'label': 'display', 'lat': -8.06667714380302...     -8.066677
# 2  [{'label': 'display', 'lat': -8.03191712550999...     -8.031917
# 3  [{'label': 'display', 'lat': -8.03080630642398...     -8.030806
# 4  [{'label': 'display', 'lat': -8.120095, 'lng':...     -8.120095
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -34.894879                   NaN           50070-230             PE
# 1    -34.890970                   NaN           50070-550             PE
# 2    -34.914598                   NaN           52060-210             PE
# 3    -34.918246                   NaN           52070-000             PE
# 4    -34.898285            Boa viagem           51020-290             PE
#
#                                                 name    referralId
# 0                           Hospital Unimed Recife I  v-1594409546
# 1  IMIP - Instituto de Medicina Integral Professo...  v-1594409546
# 2                                      Clínica ORTHO  v-1594409546
# 3                      Hospital de Olhos Santa Luzia  v-1594409546
# 4                      Hospital Veterinário Harmonia  v-1594409546

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 18 columns):
# categories                   30 non-null object
# hasPerk                      30 non-null bool
# id                           30 non-null object
# location.address             25 non-null object
# location.cc                  30 non-null object
# location.city                28 non-null object
# location.country             30 non-null object
# location.crossStreet         7 non-null object
# location.distance            30 non-null int64
# location.formattedAddress    30 non-null object
# location.labeledLatLngs      30 non-null object
# location.lat                 30 non-null float64
# location.lng                 30 non-null float64
# location.neighborhood        1 non-null object
# location.postalCode          16 non-null object
# location.state               28 non-null object
# name                         30 non-null object
# referralId                   30 non-null object
# dtypes: bool(1), float64(2), int64(1), object(14)
# memory usage: 4.1+ KB

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name        categories  \
# 0                            Hospital Unimed Recife I          Hospital
# 1   IMIP - Instituto de Medicina Integral Professo...          Hospital
# 2                                       Clínica ORTHO   Doctor's Office
# 3                       Hospital de Olhos Santa Luzia          Hospital
# 4                       Hospital Veterinário Harmonia      Veterinarian
# 5                                    UTI João de Deus          Hospital
# 6                                   Urct Adulto - Rhp          Hospital
# 7                             Real Hospital Português          Hospital
# 8                                        Cure Clínica       Medical Lab
# 9                               Hapclínica Boa Viagem   Doctor's Office
# 10                      Hapclínica Barão de Itamaracá   Doctor's Office
# 11    Policlínica e Maternidade Prof. Arnaldo Marques          Hospital
# 12                           Hospital Santa Teresinha          Hospital
# 13                            Real Hospital Português    Emergency Room
# 14  Hospital Metropolitano Sul Dom Helder Câmara (...          Hospital
# 15                   Hospital do Câncer de Pernambuco          Hospital
# 16                     HBL - Hospital Barão de Lucena          Hospital
# 17                      Laboratório Marcelo Magalhães   Doctor's Office
# 18                     Hospital Correia Picanço - HCP          Hospital
# 19                            Hospital Getúlio Vargas          Hospital
# 20                       Hospital da Mulher do Recife          Hospital
# 21                                      Dento Clínica  Dentist's Office
# 22                                         UPA Curado    Medical Center
# 23                                 Hospital Esperança          Hospital
# 24                            Hospital da Restauração          Hospital
# 25                         Hospital Unimed Recife III          Hospital
# 26            Alergo Imuno - Alergologia E Imunologia   Doctor's Office
# 27                                  Hospital Pedro II    Medical Center
# 28                    Rede Ciclo-Consultórios Médicos   Doctor's Office
# 29                       Policlínica Lessa de Andrade    Medical Center
#
#                                       address  cc                     city  \
# 0                         Av. Lins Petit, 140  BR                   Recife
# 1                         R. dos Coelhos, 300  BR                   Recife
# 2                  Estrada Do Encanamento 459  BR                   Recife
# 3                   Estr. do Encanamento, 909  BR                   Recife
# 4     Av. Domingos Ferreira, 3628, Boa viagem  BR                   Recife
# 5                                         NaN  BR                      NaN
# 6           Av. Gov. Agamenon Magalhães, 4760  BR                   Recife
# 7           Av. Gov. Agamenon Magalhães, 4760  BR                   Recife
# 8                         Avenida 1 Número 60  BR  Jaboatão dos Guararapes
# 9                                         NaN  BR                   Recife
# 10    Rua Barão de Itamaracá, 142, Espinheiro  BR                   Recife
# 11                         Av. Dois Rios, s/n  BR                   Recife
# 12                                        NaN  BR                   Recife
# 13  Av. Conselheiro Aguiar, 2502 - Boa Viagem  BR                   Recife
# 14                     Rod. BR-101 Sul, Km 28  BR  Cabo de Santo Agostinho
# 15                      Av. Cruz Cabugá, 1597  BR                   Recife
# 16                          Av. Caxangá, 3860  BR                   Recife
# 17                          R. Raul Azedo,252  BR                   Recife
# 18                                        NaN  BR                   Recife
# 19                   Av. Gal. San Martin, 200  BR                   Recife
# 20                                      BR101  BR                   Recife
# 21                                        NaN  BR                      NaN
# 22                      Av. Leonardo da Vinci  BR  Jaboatão dos Guararapes
# 23                     R. Francisco Alves 887  BR                   Recife
# 24           Av. Gov. Agamenon Magalhães, s/n  BR                   Recife
# 25                   Rua José de Alencar, 770  BR                   Recife
# 26                   Rua José De Alencar, 725  BR                   Recife
# 27                                   São José  BR                   Recife
# 28             Rua Pacífico Dos Santos,n. 103  BR                   Recife
# 29                    Est. dos Remédios, 2416  BR                   Recife
#
#    country        crossStreet  distance  \
# 0   Brasil                NaN        90
# 1   Brasil                NaN       727
# 2   Brasil                NaN      3939
# 3   Brasil         Casa Forte      4271
# 4   Brasil                NaN      6528
# 5   Brasil                NaN       565
# 6   Brasil                NaN       427
# 7   Brasil                NaN       454
# 8   Brasil          Curado IV     11190
# 9   Brasil                NaN      6522
# 10  Brasil                NaN      1998
# 11  Brasil                NaN      8350
# 12  Brasil                NaN      6027
# 13  Brasil                NaN      5581
# 14  Brasil                NaN     24512
# 15  Brasil                NaN      3300
# 16  Brasil     R. do Palanque      5506
# 17  Brasil         Boa Viagem      4563
# 18  Brasil                NaN      3226
# 19  Brasil        Av. Caxangá      3167
# 20  Brasil                NaN      5078
# 21  Brasil                NaN      6042
# 22  Brasil  rua lobão botelho     11393
# 23  Brasil                NaN       619
# 24  Brasil                NaN       844
# 25  Brasil                NaN       500
# 26  Brasil                NaN       532
# 27  Brasil                NaN       740
# 28  Brasil                NaN       573
# 29  Brasil           Madalena      1347
#
#                                      formattedAddress  \
# 0   [Av. Lins Petit, 140, Recife, PE, 50070-230, B...
# 1   [R. dos Coelhos, 300, Recife, PE, 50070-550, B...
# 2   [Estrada Do Encanamento 459, Recife, PE, 52060...
# 3   [Estr. do Encanamento, 909 (Casa Forte), Recif...
# 4   [Av. Domingos Ferreira, 3628, Boa viagem, Reci...
# 5                                            [Brasil]
# 6   [Av. Gov. Agamenon Magalhães, 4760, Recife, PE...
# 7   [Av. Gov. Agamenon Magalhães, 4760, Recife, PE...
# 8   [Avenida 1 Número 60 (Curado IV), Jaboatão dos...
# 9                                [Recife, PE, Brasil]
# 10  [Rua Barão de Itamaracá, 142, Espinheiro, Reci...
# 11  [Av. Dois Rios, s/n, Recife, PE, 51230-000, Br...
# 12                    [Recife, PE, 50800-000, Brasil]
# 13  [Av. Conselheiro Aguiar, 2502 - Boa Viagem, Re...
# 14  [Rod. BR-101 Sul, Km 28, Cabo de Santo Agostin...
# 15        [Av. Cruz Cabugá, 1597, Recife, PE, Brasil]
# 16  [Av. Caxangá, 3860 (R. do Palanque), Recife, P...
# 17  [R. Raul Azedo,252 (Boa Viagem), Recife, PE, 5...
# 18                               [Recife, PE, Brasil]
# 19  [Av. Gal. San Martin, 200 (Av. Caxangá), Recif...
# 20                        [BR101, Recife, PE, Brasil]
# 21                                           [Brasil]
# 22  [Av. Leonardo da Vinci (rua lobão botelho), Ja...
# 23  [R. Francisco Alves 887, Recife, PE, 50070-490...
# 24  [Av. Gov. Agamenon Magalhães, s/n, Recife, PE,...
# 25     [Rua José de Alencar, 770, Recife, PE, Brasil]
# 26     [Rua José De Alencar, 725, Recife, PE, Brasil]
# 27                     [São José, Recife, PE, Brasil]
# 28  [Rua Pacífico Dos Santos,n. 103, Recife, PE, B...
# 29  [Est. dos Remédios, 2416 (Madalena), Recife, P...
#
#                                        labeledLatLngs       lat        lng  \
# 0   [{'label': 'display', 'lat': -8.06074567313681... -8.060746 -34.894879
# 1   [{'label': 'display', 'lat': -8.06667714380302... -8.066677 -34.890970
# 2   [{'label': 'display', 'lat': -8.03191712550999... -8.031917 -34.914598
# 3   [{'label': 'display', 'lat': -8.03080630642398... -8.030806 -34.918246
# 4   [{'label': 'display', 'lat': -8.120095, 'lng':... -8.120095 -34.898285
# 5   [{'label': 'display', 'lat': -8.06487832087747... -8.064878 -34.898905
# 6   [{'label': 'display', 'lat': -8.064112, 'lng':... -8.064112 -34.897926
# 7   [{'label': 'display', 'lat': -8.06414666781536... -8.064147 -34.898221
# 8   [{'label': 'display', 'lat': -8.067394, 'lng':... -8.067394 -34.996402
# 9   [{'label': 'display', 'lat': -8.12005781822426... -8.120058 -34.897994
# 10  [{'label': 'display', 'lat': -8.04362608016112... -8.043626 -34.893780
# 11  [{'label': 'display', 'lat': -8.11855974779872... -8.118560 -34.944275
# 12  [{'label': 'display', 'lat': -8.03773944104035... -8.037739 -34.944164
# 13  [{'label': 'display', 'lat': -8.11157722714490... -8.111577 -34.891882
# 14  [{'label': 'display', 'lat': -8.25047389137540... -8.250474 -35.009305
# 15  [{'label': 'display', 'lat': -8.04161943387905... -8.041619 -34.872870
# 16  [{'label': 'display', 'lat': -8.03824756548555... -8.038248 -34.939121
# 17  [{'label': 'display', 'lat': -8.10174701981356... -8.101747 -34.886959
# 18  [{'label': 'display', 'lat': -8.03415804358344... -8.034158 -34.904636
# 19  [{'label': 'display', 'lat': -8.05176546333226... -8.051765 -34.922032
# 20  [{'label': 'display', 'lat': -8.07100079718979... -8.071001 -34.940119
# 21  [{'label': 'display', 'lat': -8.09928461359936... -8.099285 -34.934439
# 22  [{'label': 'display', 'lat': -8.08068485664956... -8.080685 -34.996593
# 23  [{'label': 'display', 'lat': -8.06709047796868... -8.067090 -34.895475
# 24  [{'label': 'display', 'lat': -8.05436168228491... -8.054362 -34.897526
# 25  [{'label': 'display', 'lat': -8.06462737165655... -8.064627 -34.891749
# 26  [{'label': 'display', 'lat': -8.06437056701389... -8.064371 -34.891153
# 27  [{'label': 'display', 'lat': -8.06690640534910... -8.066906 -34.891078
# 28  [{'label': 'display', 'lat': -8.06303310545187... -8.063033 -34.900022
# 29  [{'label': 'display', 'lat': -8.05882838316921... -8.058828 -34.906957
#
#    neighborhood postalCode state                        id
# 0           NaN  50070-230    PE  4d3791c0803ba35ddf1394fc
# 1           NaN  50070-550    PE  4bdc97582a3a0f47718cb3b6
# 2           NaN  52060-210    PE  54d0ca5d498e1de1dc2e3fd2
# 3           NaN  52070-000    PE  4c7423a3604a37045c287f49
# 4    Boa viagem  51020-290    PE  5eecf0d14595790008e31dab
# 5           NaN        NaN   NaN  54ff80e6498efaf6353456f8
# 6           NaN  50030-230    PE  5b3fe7483ba767002cd2d5bb
# 7           NaN  52010-902    PE  4bfa9f66508c0f4783404031
# 8           NaN  54270-090    PE  57bdae68498edfdbaf5536bc
# 9           NaN        NaN    PE  4f7c5701e4b032112a686c7a
# 10          NaN        NaN    PE  513735c9e4b08e9b2ab66f5f
# 11          NaN  51230-000    PE  4d84fc71e83fa1433f3970a1
# 12          NaN  50800-000    PE  4d99fed5af3d236a079f5fc7
# 13          NaN  51020-020    PE  4c6883826b25e21e56fe192f
# 14          NaN  50751-530    PE  4cbf3fce9ca85481387ab516
# 15          NaN        NaN    PE  4d08eb63611ff04d2a861dfb
# 16          NaN        NaN    PE  4c463f843f0276b097c452e7
# 17          NaN  51011-051    PE  4d68fd774c4637041bbe9bb3
# 18          NaN        NaN    PE  4dff478552b1d747f679127b
# 19          NaN  50630-060    PE  4d9baa7dc18aa35d4e0f73ff
# 20          NaN        NaN    PE  52e7aa23498e4057e2a9402d
# 21          NaN        NaN   NaN  4ee77bea490141636ca4dbf5
# 22          NaN        NaN    PE  4d8e24a8fa94370457e7fac5
# 23          NaN  50070-490    PE  4c476cc4417b20a19b90dda9
# 24          NaN  52010-903    PE  4bcdb288fb84c9b67b60223e
# 25          NaN        NaN    PE  4e8d99f0722e13d13af16c0a
# 26          NaN        NaN    PE  534be4fe498ecb6c1f9a51d3
# 27          NaN        NaN    PE  4d8341635e70224b3b38f308
# 28          NaN        NaN    PE  51ca12ece4b0887919f47f8a
# 29          NaN        NaN    PE  4ea696af2c5b614a68e0af9d

# %%
dataframe_filtered.head()
# Out:
#                                                 name       categories  \
# 0                           Hospital Unimed Recife I         Hospital
# 1  IMIP - Instituto de Medicina Integral Professo...         Hospital
# 2                                      Clínica ORTHO  Doctor's Office
# 3                      Hospital de Olhos Santa Luzia         Hospital
# 4                      Hospital Veterinário Harmonia     Veterinarian
#
#                                    address  cc    city country crossStreet  \
# 0                      Av. Lins Petit, 140  BR  Recife  Brasil         NaN
# 1                      R. dos Coelhos, 300  BR  Recife  Brasil         NaN
# 2               Estrada Do Encanamento 459  BR  Recife  Brasil         NaN
# 3                Estr. do Encanamento, 909  BR  Recife  Brasil  Casa Forte
# 4  Av. Domingos Ferreira, 3628, Boa viagem  BR  Recife  Brasil         NaN
#
#    distance                                   formattedAddress  \
# 0        90  [Av. Lins Petit, 140, Recife, PE, 50070-230, B...
# 1       727  [R. dos Coelhos, 300, Recife, PE, 50070-550, B...
# 2      3939  [Estrada Do Encanamento 459, Recife, PE, 52060...
# 3      4271  [Estr. do Encanamento, 909 (Casa Forte), Recif...
# 4      6528  [Av. Domingos Ferreira, 3628, Boa viagem, Reci...
#
#                                       labeledLatLngs       lat        lng  \
# 0  [{'label': 'display', 'lat': -8.06074567313681... -8.060746 -34.894879
# 1  [{'label': 'display', 'lat': -8.06667714380302... -8.066677 -34.890970
# 2  [{'label': 'display', 'lat': -8.03191712550999... -8.031917 -34.914598
# 3  [{'label': 'display', 'lat': -8.03080630642398... -8.030806 -34.918246
# 4  [{'label': 'display', 'lat': -8.120095, 'lng':... -8.120095 -34.898285
#
#   neighborhood postalCode state                        id
# 0          NaN  50070-230    PE  4d3791c0803ba35ddf1394fc
# 1          NaN  50070-550    PE  4bdc97582a3a0f47718cb3b6
# 2          NaN  52060-210    PE  54d0ca5d498e1de1dc2e3fd2
# 3          NaN  52070-000    PE  4c7423a3604a37045c287f49
# 4   Boa viagem  51020-290    PE  5eecf0d14595790008e31dab

# %%
dataframe_filtered.name
# Out:
# 0                              Hospital Unimed Recife I
# 1     IMIP - Instituto de Medicina Integral Professo...
# 2                                         Clínica ORTHO
# 3                         Hospital de Olhos Santa Luzia
# 4                         Hospital Veterinário Harmonia
# 5                                      UTI João de Deus
# 6                                     Urct Adulto - Rhp
# 7                               Real Hospital Português
# 8                                          Cure Clínica
# 9                                 Hapclínica Boa Viagem
# 10                        Hapclínica Barão de Itamaracá
# 11      Policlínica e Maternidade Prof. Arnaldo Marques
# 12                             Hospital Santa Teresinha
# 13                              Real Hospital Português
# 14    Hospital Metropolitano Sul Dom Helder Câmara (...
# 15                     Hospital do Câncer de Pernambuco
# 16                       HBL - Hospital Barão de Lucena
# 17                        Laboratório Marcelo Magalhães
# 18                       Hospital Correia Picanço - HCP
# 19                              Hospital Getúlio Vargas
# 20                         Hospital da Mulher do Recife
# 21                                        Dento Clínica
# 22                                           UPA Curado
# 23                                   Hospital Esperança
# 24                              Hospital da Restauração
# 25                           Hospital Unimed Recife III
# 26              Alergo Imuno - Alergologia E Imunologia
# 27                                    Hospital Pedro II
# 28                      Rede Ciclo-Consultórios Médicos
# 29                         Policlínica Lessa de Andrade
# Name: name, dtype: object
